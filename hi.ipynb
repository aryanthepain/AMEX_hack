# %% [markdown]
# ## Import library

# %%
import pandas as pd
from IPython.display import display, HTML

# %%
f = open("loc.txt")
DATA_LOC = f.readline() + '/'
f.close()

# %% [markdown]
# ## Importing Data

# %%
data_dict = pd.read_csv(DATA_LOC+"data_dictionary.csv")

# %%
train_df = pd.read_parquet(DATA_LOC+"train_data.parquet", engine='auto')

# %%
test_df = pd.read_parquet(DATA_LOC+"test_data.parquet", engine='auto')

# %% [markdown]
# ## Exploring the data

# %%
#display(HTML(data_dict.to_html()))
data_dict
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>masked_column</th>
#       <th>Description</th>
#       <th>Type</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>id1</td>
#       <td>Primary Key(masked)</td>
#       <td>Key</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>id2</td>
#       <td>Customer ID (masked)</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>id3</td>
#       <td>Offer ID</td>
#       <td>Categorical</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>id4</td>
#       <td>Event timestamp</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>id5</td>
#       <td>Event Date</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>y</td>
#       <td>Dependent Variable</td>
#       <td>Label</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>f1</td>
#       <td>Interest score of a customer with intrst_id =81-carrental-cars</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>f2</td>
#       <td>Interest score of a customer with intrst_id =90-coffee-coffee</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>f3</td>
#       <td>Interest score of a customer with intrst_id =281-shipping-b2b</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>f4</td>
#       <td>Interest score of a customer with intrst_id =199-photography-hobby</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>f5</td>
#       <td>Interest score of a customer with intrst_id =259-warehouse-b2b</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>f6</td>
#       <td>Interest score of a customer with intrst_id =285-construction-b2b</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>f7</td>
#       <td>Interest score of a customer with intrst_id =266-homefurnishing-furniture</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>f8</td>
#       <td>Interest score of a customer with intrst_id =216-restaurant_non_qsr-restaurant</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>f9</td>
#       <td>Interest score of a customer with intrst_id =3-airlines-airlines</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>f10</td>
#       <td>Interest score of a customer with intrst_id =283-professional_service-b2b</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>f11</td>
#       <td>Interest score of a customer with intrst_id =108 -electronics-electronics</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>f12</td>
#       <td>Interest score of a customer with intrst_id =138-homeimprovement-hobby</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>f13</td>
#       <td>Count of distinct page categories a customer has visited in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>f14</td>
#       <td>Whether a customer has visited Redemption page in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>f15</td>
#       <td>Whether a customer has visited MGM page in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>f16</td>
#       <td>Whether a customer has visited MR page in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>f17</td>
#       <td>Whether a customer has visited page_acq in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>f18</td>
#       <td>Whether a customer has visited travel page in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>f19</td>
#       <td>Whether a customer has visited Rewards page in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>f20</td>
#       <td>Whether a customer has visited Servicing page in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>f21</td>
#       <td>Whether a customer has visited page_assist in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>f22</td>
#       <td>Count of distinct channels a customer has used to logon to MYCA in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>f23</td>
#       <td>Whether a customer has used myca_app to logon to MYCA in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>f24</td>
#       <td>Whether a customer has used myca_ap2 to logon to MYCA in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>f25</td>
#       <td>Whether a customer has used myca_bwa to logon to MYCA in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>f26</td>
#       <td>Whether a customer has used myca_brs to logon to MYCA in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>f27</td>
#       <td>Whether a customer has used myca_web to logon to MYCA in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>f28</td>
#       <td>Cumulative impressions (with decaying weights for impressions in the past) of a CM for an OET offer_id in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>f29</td>
#       <td>Cumulative clicks (with decaying weights for clicks in the past) of a CM for an OET offer_id in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>f30</td>
#       <td>Cumulative impressions (with decaying weights for impressions in the past) of a cust_xref_id for a merchant offer in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>f31</td>
#       <td>Cumulative clicks (with decaying weights for clicks in the past) of a cust_xref_id for a Merchant offer in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>f32</td>
#       <td>Number of successfully sent emails in the last 30 days for each CM</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>f33</td>
#       <td>Number of emails clicked on in the last 30 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>f34</td>
#       <td>Number of emails opted out of in the last 30 days for each CM</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>f35</td>
#       <td>Number of clicks in the last 30 days when event_type_in in 'CLICK_SERVICELINK','ENROLL_CLICK','CLICK_FOOTERLINK','CLICK_MARKETING'</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>f36</td>
#       <td>Number of calls on IVR in the last 90 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>f37</td>
#       <td>Call Duration in seconds associated with the inbound call in the last 90 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>f38</td>
#       <td>Number of successfully sent direct emails in the last 180 days</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>f39</td>
#       <td>Spend in Lifestyle in the last 3 months</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>f40</td>
#       <td>Spend in Electronics in the last 3 months</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>f41</td>
#       <td>Spend in Restaurant in the last 3 months</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>f42</td>
#       <td>Membership level</td>
#       <td>Categorical</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>f43</td>
#       <td>Current account mile balance</td>
#       <td>Numerical</td>
#     </tr>
#     <tr>
#       <th>49
#     masked_column                                        Description  \
# 0             id1                                Primary Key(masked)
# 1             id2                               Customer ID (masked)
# 2             id3                                           Offer ID
# 3             id4                                    Event timestamp
# 4             id5                                         Event Date
# ..            ...                                                ...
# 367          f362  Total clicks on the incoming offer's industry ...
# 368          f363  CTR on the incoming offer's industry for the g...
# 369          f364    CM’s past 6 moth impressions on relevant offers
# 370          f365         CM’s past 6 moth clicks on relevant offers
# 371          f366            CM’s past 6 moth CTR on relevant offers
#
#             Type
# 0            Key
# 1              -
# 2    Categorical
# 3      Numerical
# 4      Numerical
# ..           ...
# 367    Numerical
# 368    Numerical
# 369    Numerical
# 370    Numerical
# 371    Numerical
#
# [372 rows x 3 columns]

# %%
train_df_description = train_df.describe()

# %%
display(HTML(train_df_description.to_html()))
train_df_description
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id1</th>
#       <th>id2</th>
#       <th>id3</th>
#       <th>id4</th>
#       <th>id5</th>
#       <th>y</th>
#       <th>f1</th>
#       <th>f2</th>
#       <th>f3</th>
#       <th>f4</th>
#       <th>f5</th>
#       <th>f6</th>
#       <th>f7</th>
#       <th>f8</th>
#       <th>f9</th>
#       <th>f10</th>
#       <th>f11</th>
#       <th>f12</th>
#       <th>f13</th>
#       <th>f14</th>
#       <th>f15</th>
#       <th>f16</th>
#       <th>f17</th>
#       <th>f18</th>
#       <th>f19</th>
#       <th>f20</th>
#       <th>f21</th>
#       <th>f22</th>
#       <th>f23</th>
#       <th>f24</th>
#       <th>f25</th>
#       <th>f26</th>
#       <th>f27</th>
#       <th>f28</th>
#       <th>f29</th>
#       <th>f30</th>
#       <th>f31</th>
#       <th>f32</th>
#       <th>f33</th>
#       <th>f34</th>
#       <th>f35</th>
#       <th>f36</th>
#       <th>f37</th>
#       <th>f38</th>
#       <th>f39</th>
#       <th>f40</th>
#       <th>f308</th>
#       <th>f309</th>
#       <th>f310</th>
#       <th>f311</th>
#       <th>f312</th>
#       <th>f313</th>
#       <th>f314</th>
#       <th>f315</th>
#       <th>f316</th>
#       <th>f317</th>
#       <th>f318</th>
#       <th>f319</th>
#       <th>f320</th>
#       <th>f321</th>
#       <th>f322</th>
#       <th>f323</th>
#       <th>f324</th>
#       <th>f325</th>
#       <th>f326</th>
#       <th>f327</th>
#       <th>f328</th>
#       <th>f329</th>
#       <th>f330</th>
#       <th>f331</th>
#       <th>f332</th>
#       <th>f333</th>
#       <th>f334</th>
#       <th>f335</th>
#       <th>f336</th>
#       <th>f337</th>
#       <th>f338</th>
#       <th>f339</th>
#       <th>f340</th>
#       <th>f341</th>
#       <th>f342</th>
#       <th>f343</th>
#       <th>f344</th>
#       <th>f345</th>
#       <th>f346</th>
#       <th>f347</th>
#       <th>f348</th>
#       <th>f349</th>
#       <th>f350</th>
#       <th>f351</th>
#       <th>f352</th>
#       <th>f353</th>
#       <th>f354</th>
#       <th>f355</th>
#       <th>f356</th>
#       <th>f357</th>
#       <th>f358</th>
#       <th>f359</th>
#       <th>f360</th>
#       <th>f361</th>
#       <th>f362</th>
#       <th>f363</th>
#       <th>f364</th>
#       <th>f365</th>
#       <th>f366</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>770164</td>
#       <td>770164</td>
#       <td>770164</td>
#       <td>770164</td>
#       <td>770164</td>
#       <td>770164</td>
#       <td>278506</td>
#       <td>322972</td>
#       <td>108562</td>
#       <td>68869</td>
#       <td>538354</td>
#       <td>620055</td>
#       <td>402726</td>
#       <td>535649</td>
#       <td>485906</td>
#       <td>516499</td>
#       <td>413602</td>
#       <td>527792</td>
#       <td>696</td>
#       <td>696</td>
#       <td>696</td>
#       <td>696</td>
#       <td>696</td>
#       <td>696</td>
#       <
#                                                     id1      id2     id3  \
# count                                            770164   770164  770164
# unique                                           770164    46550     757
# top     1366776_189706075_16-23_2023-11-02 22:22:00.042  1396352   92636
# freq                                                  1      510    2446
#
#                             id4         id5       y      f1      f2      f3  \
# count                    770164      770164  770164  278506  322972  108562
# unique                   763371           3       2      82      88      74
# top     2023-11-01 08:57:21.690  2023-11-01       0    13.0     9.0     1.0
# freq                          5      301698  733113   42443   33756   19425
#
#            f4  ...    f357     f358    f359 f360    f361    f362    f363  \
# count   68869  ...  587734   628173  727175  232  654412  654412  654412
# unique     65  ...    2305     2150       2    1    1951     110    8398
# top       1.0  ...     0.0  -9999.0     0.0  1.0     1.0     0.0     0.0
# freq    14848  ...   13352    53759  725345  232   42543  418293  418293
#
#           f364    f365    f366
# count   661850  661850  661850
# unique    3893     505   18084
# top       51.0     0.0     0.0
# freq      6773  205968  205968
#
# [4 rows x 372 columns]

# %%
test_df_description = test_df.describe()

# %%
display(HTML(test_df_description.to_html()))
test_df_description
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>
# count                    369301      369301  131879  155016  49747  30494
# unique                   365544           2      82      88     74     64
# top     2023-11-04 07:55:02.690  2023-11-05    13.0     9.0    1.0    1.0
# freq                          5      186895   19699   17325   9080   6620
#
#             f5  ...                 f357     f358    f359 f360    f361  \
# count   257014  ...               362575   369293  347489  113  316481
# unique      94  ...                 1380     1275       2    1    1636
# top        6.0  ...  -0.0187831003184442  -9999.0     0.0  1.0     1.0
# freq     15829  ...                  871     6726  347057  113   19751
#
#           f362    f363    f364    f365    f366
# count   316481  316481  318139  318139  318139
# unique      99    5435    3108     361   11184
# top        0.0     0.0    54.0     0.0     0.0
# freq    200569  200569    2804  100915  100915
#
# [4 rows x 371 columns]

# %%
# Vibha Data Preprocessing (f219 - f366)
all_columns = train_df.columns.tolist()

start_col = 'f219'
end_col = 'f366'

start_idx = all_columns.index(start_col)
end_idx = all_columns.index(end_col)

target_columns = all_columns[start_idx:end_idx + 1]

print(f"Total grouped columns: {len(target_columns)}")
print(target_columns[:5])  

# train_df[target_columns] = train_df[target_columns].fillna(train_df[target_columns].median())
# Out:
# Total grouped columns: 148
# ['f219', 'f220', 'f221', 'f222', 'f223']

# %%
null_counts = train_df[target_columns].isnull().sum()

null_counts[null_counts > 0]
# Out:
# f219    281290
# f220    746072
# f221    762406
# f222    283575
# f223        18
#          ...
# f362    115752
# f363    115752
# f364    108314
# f365    108314
# f366    108314
# Length: 146, dtype: int64

# %%
null_counts[null_counts > 0].sort_values(ascending=False)
# Out:
# f360    769932
# f221    762406
# f220    746072
# f222    283575
# f219    281290
#          ...
# f301        18
# f300        18
# f299        18
# f298        18
# f292        18
# Length: 146, dtype: int64

# %%
train_df.isnull().sum().sum()
# Out:
# 68296406

# %%
for col, val in null_counts[null_counts > 0].sort_values(ascending=False).items():
    print(f"{col}: {val}")
# Out:
# f360: 769932
# f221: 762406
# f220: 746072
# f222: 283575
# f219: 281290
# f347: 197029
# f348: 197029
# f325: 195753
# f329: 195753
# f310: 195741
# f326: 195738
# f330: 195738
# f331: 195737
# f328: 195737
# f327: 195737
# f311: 195737
# f312: 195737
# f313: 192403
# f320: 182430
# f324: 182430
# f323: 182430
# f322: 182430
# f321: 182430
# f318: 182430
# f319: 182430
# f317: 182430
# f316: 182430
# f315: 182430
# f314: 182430
# f355: 182430
# f356: 182430
# f357: 182430
# f358: 141991
# f351: 141991
# f354: 141991
# f353: 141991
# f352: 141991
# f341: 132302
# f336: 132103
# f342: 131255
# f337: 130900
# f343: 130276
# f338: 129921
# f340: 129894
# f339: 129894
# f344: 129880
# f346: 129880
# f345: 129880
# f362: 115752
# f361: 115752
# f363: 115752
# f365: 108314
# f364: 108314
# f366: 108314
# f359: 42989
# f273: 18
# f251: 18
# f246: 18
# f247: 18
# f248: 18
# f249: 18
# f335: 18
# f334: 18
# f333: 18
# f332: 18
# f250: 18
# f252: 18
# f244: 18
# f253: 18
# f254: 18
# f255: 18
# f256: 18
# f257: 18
# f258: 18
# f259: 18
# f260: 18
# f245: 18
# f243: 18
# f274: 18
# f242: 18
# f223: 18
# f224: 18
# f225: 18
# f226: 18
# f227: 18
# f228: 18
# f229: 18
# f230: 18
# f231: 18
# f232: 18
# f233: 18
# f234: 18
# f235: 18
# f236: 18
# f237: 18
# f238: 18
# f239: 18
# f240: 18
# f241: 18
# f261: 18
# f262: 18
# f263: 18
# f295: 18
# f293: 18
# f272: 18
# f291: 18
# f290: 18
# f289: 18
# f288: 18
# f287: 18
# f286: 18
# f285: 18
# f284: 18
# f283: 18
# f282: 18
# f281: 18
# f280: 18
# f279: 18
# f278: 18
# f277: 18
# f276: 18
# f275: 18
# f294: 18
# f296: 18
# f264: 18
# f297: 18
# f265: 18
# f266: 18
# f267: 18
# f268: 18
# f269: 18
# f270: 18
# f271: 18
# f309: 18
# f308: 18
# f307: 18
# f306: 18
# f305: 18
# f304: 18
# f303: 18
# f302: 18
# f301: 18
# f300: 18
# f299: 18
# f298: 18
# f292: 18

# %%
null_counts = train_df.isnull().sum()
total_rows = len(train_df)

# %%
high_null_cols = null_counts[null_counts > 0.6 * total_rows].index.tolist()
moderate_null_cols = null_counts[(null_counts > 0.1 * total_rows) & (null_counts <= 0.6 * total_rows)].index.tolist()
low_null_cols = null_counts[(null_counts > 0) & (null_counts <= 0.1 * total_rows)].index.tolist()

# %%
data_dict['Description'] = data_dict['Description'].astype(str).str.strip()
data_dict['Type'] = data_dict['Type'].astype(str).str.strip().str.lower()

categorical_cols = data_dict[data_dict['Type'].str.contains('categorical')]['Description'].tolist()
one_hot_cols = data_dict[data_dict['Type'].str.contains('one hot')]['Description'].tolist()
numerical_cols = data_dict[data_dict['Type'].str.contains('numerical')]['Description'].tolist()

categorical_cols = [col for col in categorical_cols if col in train_df[target_columns].columns]
one_hot_cols = [col for col in one_hot_cols if col in train_df[target_columns].columns]
numerical_cols = [col for col in numerical_cols if col in train_df[target_columns].columns]

# Output counts for verification
len(categorical_cols), len(one_hot_cols), len(numerical_cols)
# Out:
# (0, 0, 0)

# %%
# High-missing
for col in high_null_cols:
    if col in numerical_cols:
        train_df[col] = train_df[col].fillna(0)
    elif col in one_hot_cols:
        train_df[col] = train_df[col].fillna(0)
    elif col in categorical_cols:
        train_df[col] = train_df[col].fillna('missing')

# Moderate-missing
for col in moderate_null_cols:
    if col in numerical_cols:
        train_df[col] = train_df[col].fillna(train_df[col].median())
    elif col in one_hot_cols:
        train_df[col] = train_df[col].fillna(0)
    elif col in categorical_cols:
        train_df[col] = train_df[col].fillna(train_df[col].mode()[0])

# Low-missing
for col in low_null_cols:
    if col in numerical_cols:
        train_df[col] = train_df[col].fillna(train_df[col].median())
    elif col in one_hot_cols:
        train_df[col] = train_df[col].fillna(0)
    elif col in categorical_cols:
        train_df[col] = train_df[col].fillna(train_df[col].mode()[0])
